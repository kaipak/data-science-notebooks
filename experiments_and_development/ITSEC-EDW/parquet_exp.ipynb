# %%
import pandas as pd
import numpy as np

# %%
df_prog_sum = pd.read_csv("/Users/kaipak/Desktop/cyber-vulnerability/data/itsec-edw"
                          "/cleaned_files/ALL_PATCHES/summaries/itsec-continuing-progress-summary.csv")
df_burdown = pd.read_csv("/Users/kaipak/Desktop/cyber-vulnerability/data/itsec-edw"
                        "/cleaned_files/ALL_PATCHES/summaries/itsec-continuing-progress-burdown.csv")
df_allpatches = pd.read_csv("/Users/kaipak/Desktop/cyber-vulnerability/data/itsec-edw"
                        "/cleaned_files/ALL_PATCHES/summary/all_patches_summary.csv")
# Out:
# /Users/kaipak/miniconda3/envs/kai/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,1,6,8,12,13,14,15,17,21,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_prog_sum.to_parquet("/Users/kaipak/Desktop/cyber-vulnerability/data/dev/itsec-continuing-progress-summary.parquet")
df_burdown.to_parquet("/Users/kaipak/Desktop/cyber-vulnerability/data/dev/itsec-continuing-progress-burdown.parquet")
df_allpatches.to_parquet("/Users/kaipak/Desktop/cyber-vulnerability/data/dev/all_patches_summary.parquet")

# %%
df_pq = pd.read_parquet("/Users/kaipak/Desktop/cyber-vulnerability/data/dev/test.pq")

# %%
df_pq.shape
# Out:
# (8803814, 26)

# %%
df_big.shape
# Out:
# (8803814, 26)

# %%
df_allpatches.head()
# Out:
#          Date raw_v_adj_flag       Security Plan  \
# 0  11/09/2021       adjusted  CD-9999-M-JPL-0011
# 1  11/09/2021       adjusted  CD-9999-M-JPL-0011
# 2  11/09/2021       adjusted  CD-9999-M-JPL-0011
# 3  11/09/2021       adjusted  CD-9999-M-JPL-0011
# 4  11/09/2021       adjusted  CD-9999-M-JPL-0011
#
#                      Security Plan Name  \
# 0  Flight Operations Ground Data System
# 1  Flight Operations Ground Data System
# 2  Flight Operations Ground Data System
# 3  Flight Operations Ground Data System
# 4  Flight Operations Ground Data System
#
#                        Security Plan Name (Adjusted)  \
# 0  Flight Operations Ground Data System (CD-9999-...
# 1  Flight Operations Ground Data System (CD-9999-...
# 2  Flight Operations Ground Data System (CD-9999-...
# 3  Flight Operations Ground Data System (CD-9999-...
# 4  Flight Operations Ground Data System (CD-9999-...
#
#                                   Vulnerability Name NASA Severity  \
# ...

# %%
df_prog_sum.head()
# Out:
#                  Center Name CVE List       Security Plan      Device Name  \
# 0  Jet Propulsion Laboratory      NaN  NN-9999-M-JPL-4748        MT-200974
# 1  Jet Propulsion Laboratory      NaN  OA-9999-M-JPL-4838     AP-SCCM-SP02
# 2  Jet Propulsion Laboratory      NaN  OA-9999-M-JPL-4838      AV-FIM-SP01
# 3  Jet Propulsion Laboratory      NaN  OA-9999-M-JPL-4839         7920TEST
# 4  Jet Propulsion Laboratory      NaN  OA-9999-M-JPL-4839  DESKTOP-B4SQKHU
#
#                        DNS Name NASA Severity    Platform Type  \
# 0        MT-200974.jpl.nasa.gov      Critical       Windows 10
# 1       ap-sccm-sp02.RES.AD.JPL      Critical  Windows 2012 R2
# 2        av-fim-sp01.RES.AD.JPL      Critical  Windows 2012 R2
# 3         7920Test.jpl.nasa.gov          High       Windows 10
# 4  DESKTOP-B4SQKHU.jpl.nasa.gov      Critical       Windows 10
#
#      Platform Category              Operating System  \
# 0  Windows Workstation  Win10 10.0.18363.1316 (1909)
# ...
