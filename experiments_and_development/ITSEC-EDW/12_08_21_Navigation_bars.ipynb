# %% [markdown]
# # Navigation and/& Mission Bars
# Same project plan seems to have issues because of SC/NN changes.

# %%
import pandas as pd
import numpy as np

pd.set_option('max_columns', None)
pd.set_option('max_rows', 100)

# %%
df_bur = pd.read_csv('/Users/kaipak/Desktop/cyber-vulnerability/data/itsec-edw/cleaned_files'
                     '/HIGH_CRITICAL/summaries/itsec-continuing-progress-burdown.csv')

# %%
df_today = df = pd.read_csv('/Users/kaipak/Desktop/cyber-vulnerability/data/itsec-edw/raw_files/ITSECEDW_12_10_2021.csv',
                encoding= 'unicode_escape', header=1)

# %%
df_bur.loc[df_bur['Security Plan Name (Adjusted)'].str.contains('0662', na=False)]
# Out:
#           Security Plan                           Security Plan Name  \
# 294  SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed
# 295  SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed
# 296  SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed
# 297  SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed
# 605  SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed
# 606  SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed
# 607  SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed
# 608  SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed
#
#     NASA Severity        burndown_flag NASA_Mission  count    pct_ch  \
# 294      Critical       baseline (raw)         CORP   1119  0.000000
# 295      Critical          today (raw)      MISSION    198 -0.823056
# 296          High       baseline (raw)         CORP   4220  0.000000
# ...

# %%
df_today.loc[df_today['Security Plan'].str.contains('0662', na=False)].groupby(by=['Security Plan', 'Security Plan Name', 'Is Mission']).size()
# Out:
# Security Plan       Security Plan Name                           Is Mission
# SC-9999-M-JPL-0662  Mars 2020 Work Station Test Set and Testbed  1.0           2440
# dtype: int64

# %%
df_bar.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1y/9ndq9fyj33d9xdqgm6r3jtfw0000gq/T/ipykernel_63067/4084884272.py in <module>
# ----> 1 df_bar.shape
#
# NameError: name 'df_bar' is not defined
