# %%
import sys, os


from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://pds-ppi.igpp.ucla.edu/software/index.jsp"
req = requests.get(url)
soup = BeautifulSoup(req.text, "html.parser")

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /index.jsp
# http://www.nasa.gov/
# /sitehelp.jsp
# /feedback.jsp
# https://pds.nasa.gov/contact/pb-search/
# /index.jsp
# /overview.jsp
# /search/index.jsp
# /search/annex/
# /doc/index.jsp
# /software/index.jsp
# /personnel.jsp
# /related_sites.jsp
# https://pds.jpl.nasa.gov/home/about/
# /mission
# /faq.jsp
# /citations_policy.jsp
# /search?e=
# /help_users.jsp
# /help_reviewers.jsp
# /help_providers.jsp
# http://pds.jpl.nasa.gov/
# http://pds-atmospheres.nmsu.edu/
# http://pds-geosciences.wustl.edu/
# https://pds-imaging.jpl.nasa.gov/
# https://naif.jpl.nasa.gov/naif/index.html
# https://pds-rings.seti.org/
# https://pds-smallbodies.astro.umd.edu/
# https://pdsmgmt.gsfc.nasa.gov/
# http://release.igpp.ucla.edu/igpp/mimic/
# /software/ditdos.jsp
# /software/splash/index.jsp
# https://github.com/houston-igpp/pdsppi-review-website
# http://release.igpp.ucla.edu/pds/cdf/
# http://release.igpp.ucla.edu/igpp/docgen/
# /software/ruleset/docs/PPIRulesetLanguage.pdf
# /software/ruleset/docs/Labeler.pdf
# /software/ruleset/labeler/index.jsp
# /software/Index/index.jsp
# /software/Index/Index.jar
# /software/jar/ruleset.jar
# /software/jar/pdsppi.jar
# /software/jar/plugin.jar
# /software/cassiniFFHscan.jsp
# /software/compare.jsp
# /software/FFHScan.jsp
# /software/formatdescription.jsp
# /software/imath.jsp
# /software/labelvalue.jsp
# /software/lookup.jsp
# /software/spreadsheet.jsp
# /software/pchronos.jsp
# /software/pvotab.jsp
# /software/strings.jsp
# /software/tabstartstop.jsp
# /software/targetphrase.jsp
# /software/time.jsp
# /software/jar/plugin.jar
# /software/labelparser.jsp
# /software/ppi_option.jsp
# /software/ppi_ruleset.jsp
# /software/ppi_table.jsp
# /software/general/pdsppi.zip
# /software/jar/pdsppi.jar
# https://pds-geosciences.wustl.edu/missions/mro/sharad_3d.htm
# https://pds.jpl.nasa.gov/datasearch/subscription-service/SS-20211014.shtml
# https://pds.jpl.nasa.gov/datasearch/subscription-service/SS-20211001.shtml
# https://pds.jpl.nasa.gov/datasearch/subscription-service/SS-Release.shtml
# https://pds.nasa.gov/home/proposers/proposing-programs.shtml
# https://pds.nasa.gov/home/proposers/Mission-Proposers-Archive-Guide-v4-r5.pdf
# https://pds.nasa.gov/tools/dd-search/
# https://pds.jpl.nasa.gov/datastandards/documents/
# https://pds.nasa.gov/datastandards/about/
# https://pds.jpl.nasa.gov/datasearch/subscription-service/top.cfm
# https://pds.nasa.gov/datastandards/pds3/
# http://www.adsabs.harvard.edu/
# http://www.nasa.gov/
# http://www.jpl.nasa.gov/imagepolicy/
# http://www.hq.nasa.gov/office/pao/FOIA/
# http://www.nasa.gov/
# mailto:pds_operator@igpp.ucla.edu

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html>
# <head>
# <title>PDS/PPI Home Page </title>
# <meta content="ALL" name="ROBOTS"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="PDS/PPI Home Page" name="description"/>
# <meta content="UCLA, IGPP, institute, geophysics, space, physics, magnetosphere, science, earth, solar system, spacecraft, education, research, nasa, pds,ppi,The Planetary Plasma Interactions Node " name="keywords"/>
# <script>
#
# if(window.location.search.indexOf("onfocus")!=-1){
# 	window.location.search="";
# }
# if(window.location.search.indexOf("alert")!=-1){
# 	window.location.search="";
# 	//window.history.pushState("PDS PPI Home page", "PDS PPI Home page", "../index.jsp");
# }
#
# var pathname =window.location.pathname;
#
# if(pathname.indexOf('project/maven')==1){
# 	window.location.href='/mission/MAVEN';
# }
#
#
# </script>
# <link href="/theme/css/ppi.css" rel="stylesheet" type="text/css"/>
# <link href="/theme/css/expand.css" rel="stylesheet" type="text/css"/>
# <link href="/theme/css/project.css" rel="stylesheet" type="text/css"/>
# <link href="/theme/css/custom-theme/jquery-ui-1.8.custom.css" rel="stylesheet" type="text/css"/>
# <script src="/theme/js/jquery.js" type="text/javascript"></script>
# <script src="/theme/js/jquery-1.4.2.min.js" type="text/javascript"></script>
# <script src="/theme/js/jquery-ui-1.8.custom.min.js" type="text/javascript"></script>
# <script src="/theme/js/jquery.ui.datepicker.js" type="text/javascript"></script>
# <script src="/theme/js/ppi.js" type="text/javascript"></script>
# <script src="/theme/js/expand.js" type="text/javascript"></script>
# <script src="/theme/js/preview.js" type="text/javascript"></script>
# <script src="/theme/js/thickbox.js" type="text/javascript"></script>
# <script src="/theme/jquery/jquery-1.9.1.js" type="text/javascript"></script>
# <script src="/theme/jquery/jquery-ui.js" type="text/javascript"></script>
# <script src="/theme/jquery/jquery.cookie.js" type="text/javascript"></script>
# <script src="/theme/jquery/jquery.popupwindow.js" type="text/javascript"></script>
# <!--  cript type="text/javascript" src="/manage/data/targets.js"></script -->
# <script src="/pds-app-bar/pds-app-bar.js" type="text/javascript"></script>
# <link href="/pds-app-bar/pds-app-bar.css" rel="stylesheet" type="text/css"/>
# <link href="/theme/css/thickbox.css" media="screen" rel="stylesheet" type="text/css"/>
# <style type="text/css">
#
# 			#dialog_link {padding: .4em 1em .4em 20px;text-decoration: none;position: relative;}
# 			#dialog_link span.ui-icon {margin: 0 5px 0 0;position: absolute;left: .2em;top: 50%;margin-top: -8px;}
# 			#example_link {padding: .4em 1em .4em 20px;text-decoration: none;position: relative;}
# 			#example_link span.ui-icon {margin: 0 5px 0 0;position: absolute;left: .2em;top: 50%;margin-top: -8px;}
# 			ul#icons {padding: .4em 1em .4em 20px;text-decoration: none;position: relative;}
# 			ul#icons li {margin: 2px; position: relative; padding: 4px 0; cursor: pointer; float: left;  list-style: none;}
# 			ul#icons span.ui-icon {margin: 0 5px 0 0;position: absolute;left: .2em;top: 50%;margin-top: -8px;}
# 		</style>
# <script>
# function mycomparator(a,b) {
# 	  return parseInt(a.no) - parseInt(b.no);
# }
# var setRight= Boolean('true');
# var setLeft=Boolean('true');
# if(!setRight){
# var width = $('#centercontents').width();
# $('#centercontents').css('width', '780 px');
# }
#
# var profiles =
# {
# 	window800:
# 	{
# 		height:800,
# 		width:800,
# 		status:1
# 	},
#
# 	window200:
# 	{
# 		height:200,
# 		width:200,
# 		status:1,
# 		resizable:0
# 	},
#
# 	windowCenter:
# 	{
# 		height:300,
# 		width:400,
# 		center:1
# 	},
#
# 	windowNotNew:
# 	{
# 		height:300,
# 		width:400,
# 		center:1,
# 		createnew:0
# 	},
#
# 	windowCallUnload:
# 	{
# 		height:300,
# 		width:400,
# 		center:1,
# 		onUnload:unloadcallback
# 	},
#
# };
#
# function unloadcallback(){
# 	alert("unloaded");
# };
#
#
# 	$(function()
# {
# 		$(".popupwindow").popupwindow(profiles);
# 	});
# </script>
# </head>
# <body>
# <div id="container">
# <div id="menunav">
# <div id="maintop"><a href="/index.jsp"><img alt="" border="0" height="23" src="/theme/images/home/ppi_home_01.gif" width="1000"/></a></div>
# <div id="mainbanner">
# <table cellpadding="0" cellspacing="0" style="background-image:url('/theme/images/home/top_banner.gif');" width="100%">
# <tr><td height="69" width="630"></td>
# <td class="header_text">
# <ul>
# <li><a href="http://www.nasa.gov/">NASA Portal</a></li>
# <li><a href="/sitehelp.jsp">Site Help</a></li>
# <li><a href="/feedback.jsp">Feedback</a></li>
# <li><a href="https://pds.nasa.gov/contact/pb-search/">Phone Book</a></li>
# </ul>
# </td></tr>
# </table>
# </div>
# <script>
# 	$(function() {
# 		$( "#searchKey" ).autocomplete({
# 			source:"/autocomplete",
# 			max: 5,
# 			minlength:2});
#
# 		$( "#k" ).autocomplete({
# 			source:"/autocomplete",
# 			max: 5,
# 			minlength:2});
# 	});
# 	</script>
# <div id="mainsearch">
# <!-- search form from header -->
# <form action="/search.jsp" method="post">
# <table cellpadding="0" cellspacing="0" class="search_text">
# <tr><td width="20"></td><td class="header_text" colspan="3">Search For:</td></tr>
# <tr><td width="20"></td><td><div class="ui-widget"><input class="input_text" id="searchKey" name="searchKey" size="20" type="text" value=""/></div></td><td><input class="input_text" type="submit" value="Go"/></td></tr>
# <tr><td width="20"></td><td class="header_text" colspan="3">in
# 					<select class="input_text" id="searchOption" name="searchOption" size="1">
# <option value="PPI Data Holdings">PPI Data Holdings</option>
# <option value="PDS phone book">PDS Phone Book</option>
# <option value="PDS Data Dictionary">PDS Data Dictionary</option>
# <option value="References">References</option>
# </select>
# </td>
# </tr>
# </table>
# </form>
# </div>
# <div id="mainmenu">
# <ul>
# <li><a href="/index.jsp">HOME</a></li>
# <li><a href="/overview.jsp">OVERVIEW</a></li>
# <li><a href="/search/index.jsp">DATA</a></li>
# <li><a href="/search/annex/">ANNEX</a></li>
# <li><a href="/doc/index.jsp">DOCUMENTS</a></li>
# <li><a class="selected" href="/software/index.jsp">SOFTWARE</a></li>
# <li><a href="/personnel.jsp">PERSONNEL</a></li>
# <li><a href="/related_sites.jsp">RELATED SITES</a></li>
# <li><a href="https://pds.jpl.nasa.gov/home/about/">ABOUT PDS</a></li>
# </ul>
# </div>
# <div id="submenu">
#
# </div>
# <div id="contents">
# <div id="leftsidebar">
# <div class="quicksearch">
# <p class="sidebartitle" id="quicksearch_title">QUICK SEARCH</p>
# <div class="searchtext" id="quicksearch_content">
# <table id="leftmenu_summary">
# <!-- <tr><td colspan=2><a href="/search/advanced_search.jsp">Advanced Search</a></td></tr>
# 		<tr><td colspan=2><a href="/search/lists.jsp?m=list&facet=INSTRUMENT_TYPE&title=List By Instrument">List By Instrument</a></td></tr> -->
# <!-- <tr><td colspan=2><a href="/search/lists.jsp?m=list&facet=MISSION_NAME&title=List By Missions">List By Missions</a></td></tr> -->
# <tr><td colspan="2"><a href="/mission"> Search By Missions</a></td></tr>
# <tr><td colspan="2" height="10"></td></tr>
# <script>
# 			var planet =  JSON.parse(getPlanet());
# 			for(var i=0; i<planet.length; i++){
# 					document.write("<tr><td>");
# 					var target_icon;
# 					if(typeof(planet[i].logo)!="undefined"){
# 						for(var j=0; j<planet[i].logo.length; j++){
# 							var logosrc=planet[i].logo[j].src;
#
# 							if(logosrc.indexOf("80")>-1){
# 								target_icon="/gallery/Planet/logo/"+logosrc;
# 							}
#
# 						}
#
# 					}
# 					var name = planet[i].name;
# 					//var tr =  document.createElement('tr');
# 					var e=name.indexOf("(");
# 					var link_name=name.replace("(","&#40;").replace(")", "&#41;");
# 					var rep_name=name
# 					link_name=name.replace(/ /g, "_");
# 					temp="<tr><td>";
#
# 					if(e>0 && name.length>20){
# 						rep_name= name.substring(0,e);
# 					}
# 					document.write("<a href=\"/search/?t="+link_name+"&facet=TARGET_NAME\"><img src='"+target_icon+"' border=0 width='20'></a></td><th valign=top><a href=\"/search/?t="+link_name+"&facet=TARGET_NAME\">"+rep_name+"</a></th></tr>");
# 					//document.write("<a href='/search/target/?t="+link_name+"'><img src='"+target_icon+"' border=0 width='20'></a></td><th valign=top><a href='/search/target/?t="+link_name+"'>"+rep_name+"</a></th></tr>");
# 			}
#
#
#
# 			</script>
# </table>
# </div>
# </div>
# <div class="quicksearch">
# <p class="sidebartitle">QUICK LINKS</p>
# <div class="searchtext">
# <a href="/faq.jsp">FAQ</a><br/>
# <a href="/citations_policy.jsp">Citation Policy</a><br/>
# <!--  <a href="/search?dp=">Data Producer</a><BR>
# 			<a href="/search?ds=">Data Supplier</a><BR>-->
# <a href="/search?e=">Errata for all volumes</a><br/>
# <a href="/help_users.jsp">Help for Data Users</a><br/>
# <a href="/help_reviewers.jsp">Help for Data Reviewers</a><br/>
# <a href="/help_providers.jsp">Help for Data Providers</a>
# </div>
# </div>
# <div class="quicksearch">
# <p class="sidebartitle">PDS NODES</p>
# <div class="searchtext">
# <a href="http://pds.jpl.nasa.gov/">PDS Home</a><br/>
# <a href="http://pds-atmospheres.nmsu.edu/">Atmospheres</a><br/>
# <a href="http://pds-geosciences.wustl.edu/">Geosciences</a><br/>
# <a href="https://pds-imaging.jpl.nasa.gov/">Cartography and Imaging Sciences</a><br/>
# <a href="https://naif.jpl.nasa.gov/naif/index.html">NAIF - SPICE</a><br/>
# <a href="https://pds-rings.seti.org/">Ring-Moon Systems</a><br/>
# <a href="https://pds-smallbodies.astro.umd.edu/">Small Bodies</a><br/>
# <a href="https://pdsmgmt.gsfc.nasa.gov/">Management</a>
# </div>
# </div>
# </div>
# <div id="centercontents">
# <table class="main_contexts_text" width="569">
# <tr><td colspan="2"><img alt="" src="/theme/images/software/software_header.gif"/></td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td class="header_contexts_text" colspan="2">PPI Software Releases</td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td colspan="2">
# <table width="100%">
# <tr><td valign="top" width="80"><a href="http://release.igpp.ucla.edu/igpp/mimic/">igpp.mimic</a></td><td>A
# 						set of tools to create mirrors of file collections. It uses a
# 						combination of techniques to optimize the synchronization of the
# 						collections. Mimic can use either the HTTP, SSH or FTP protocol to copy
# 						files. It supports both pushing files to remote locations or pulling
# 						files from remote locations.</td></tr>
# <tr><td valign="top" width="80"><a href="/software/ditdos.jsp">ditdos</a></td><td>DITDOS web service which provides access to data archives. It can build inventories of data holdings, present organized views of the inventory and assist in downloading data collections. </td></tr>
# <tr><td valign="top"><a href="/software/splash/index.jsp">SPLASH</a></td><td> SPLASH is an interactive data display application that runs on Microsoft Windows platforms.</td></tr>
# <tr><td valign="top"><a href="https://github.com/houston-igpp/pdsppi-review-website">Review</a></td><td>PDS-PPI Review Website provides service for conducting and managing peer-reviews.</td></tr>
# </table>
# </td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td class="header_contexts_text" colspan="2">PDS4 Software Releases</td></tr>
# <tr><td colspan="2">Here are the tools and utilities that are available from the PPI Node
# for use with PDS4. </td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td colspan="2"><span class="red_header">Applications</span></td></tr>
# <tr><td colspan="2">
# <table width="100%">
# <tr><td valign="top" width="80"><a href="http://release.igpp.ucla.edu/pds/cdf/">pds.cdf</a></td><td>A Java class library for reading files stored in the Common Data Format (CDF)</td></tr>
# <tr><td valign="top" width="80"><a href="http://release.igpp.ucla.edu/igpp/docgen/">igpp.docgen</a></td><td>The igpp-docgen tool is a document generator based on Apache Velocity. The tool can process template documents written in Velocity Template Language (VTL). It can read PDS3 labels, text files containing keyword=value pairs, and spreadsheets in CSV or TAB format. The content of each processed files are assigned to variables in separate Velocity contexts and can be referenced in the Velocity template file. The output format can be PDS3 or XML. </td></tr>
# </table>
# </td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td class="header_contexts_text" colspan="2">PDS3 Software</td></tr>
# <tr><td colspan="2">Here are the tools and utilities that are available from the PPI Node
# for use with PDS3. </td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td colspan="2"><span class="red_header">Document</span></td></tr>
# <tr><td colspan="2">
# <table width="100%">
# <tr><td><a href="/software/ruleset/docs/PPIRulesetLanguage.pdf">Ruleset Language</a></td><td>A description of the Ruleset Language</td></tr>
# <tr><td width="200"><a href="/software/ruleset/docs/Labeler.pdf">Labeler and Ruleset Processing</a></td><td>Presented at the PDS Technical Session, July 2003</td></tr>
# </table>
# </td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td colspan="2"><span class="red_header">Applications</span></td></tr>
# <tr><td colspan="2">
# <table>
# <tr><td valign="top"><a href="/software/ruleset/labeler/index.jsp" id="labeler">labeler</a></td><td>A Java application which uses the Ruleset Processor to generate PDS labels for files.</td></tr>
# <tr><td valign="top"><a href="/software/Index/index.jsp" id="ig">Index</a></td><td>A Java application to generate PDS compliant index files for a volume.</td></tr>
# </table>
# </td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td colspan="2"><span class="red_header">JAR files - Quick link</span></td></tr>
# <tr><td colspan="2">
# <table>
# <tr><td valign="top" width="80"><a href="/software/Index/Index.jar">Index.jar</a></td><td>Index generation application.</td></tr>
# <!-- <tr><td valign="top"><a href="/software/jar/inventory.jar">inventory.jar</a></td><td>Inventory generation application.</td></tr> -->
# <tr><td valign="top"><a href="/software/jar/ruleset.jar">ruleset.jar</a></td><td>Ruleset-based label generator.</td></tr>
# <tr><td valign="top"><a href="/software/jar/pdsppi.jar">pdsppi.jar</a></td><td>File containing all PDS/PPI classes.</td></tr>
# <tr><td valign="top"><a href="/software/jar/plugin.jar">plugin.jar</a></td><td>File containing all plug-ins.</td></tr>
# <tr><td colspan="2"><i>How to Install?<br/>Download and place in your Java CLASS_PATH (typically $JAVA_HOME/jre/lib/ext)</i></td></tr>
# </table>
# </td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td colspan="2"><span class="red_header">Plug-ins for use with Ruleset Processor</span></td></tr>
# <tr><td colspan="2">
# <table>
# <tr><td valign="top"><a href="/software/cassiniFFHscan.jsp">CassiniFFHScan</a></td><td>Extract information from a Cassini Flatfile.</td></tr>
# <tr><td><a href="/software/compare.jsp">Compare</a></td><td>Perform a relational compare two strings or numbers.</td></tr>
# <tr><td><a href="/software/FFHScan.jsp">FFHScan</a></td><td>Extract information from a Flatfile.</td></tr>
# <tr><td><a href="/software/formatdescription.jsp">FormatDescription</a></td><td>Word wrap and indent text.</td></tr>
# <tr><td><a href="/software/imath.jsp">IMath</a></td><td>Perform simple integer math.</td></tr>
# <tr><td><a href="/software/labelvalue.jsp">LabelValue</a></td><td>Extract a value from a label.</td></tr>
# <tr><td><a href="/software/lookup.jsp">Lookup</a></td><td>Find a value in an interval lookup spreadsheet.</td></tr>
# <tr><td><a href="/software/spreadsheet.jsp">SpreadSheet</a></td><td>Parse files containing a spreadsheet (delimited text) and determine metrics.</td></tr>
# <tr><td><a href="/software/pchronos.jsp">PChronos</a></td><td>Interface to the NAIF/SPICE "chronos" utility.</td></tr>
# <tr><td><a href="/software/pvotab.jsp">PvoTabProperties</a></td><td>Extract first and last values in the table.</td></tr>
# <tr><td><a href="/software/strings.jsp">Strings</a></td><td>Determine length, change case, index, and subset strings.</td></tr>
# <tr><td><a href="/software/tabstartstop.jsp">TabStartStop</a></td><td>Return a portion (column) of the first and last rows in an ASCII table.</td></tr>
# <tr><td><a href="/software/targetphrase.jsp">TargetPhrase</a></td><td>Create a properly punctuated phrase describing a list a values.</td></tr>
# <tr><td><a href="/software/time.jsp">Time</a></td><td>Parse and construct time strings in many formats.<br/></td></tr>
# <tr><td><a href="/software/jar/plugin.jar">plugin.jar</a></td><td>File containing all plug-ins.</td></tr>
# </table>
# </td></tr>
# <tr><td align="left" colspan="2"><img alt="" height="24" src="/theme/images/home/ppi_home_25.gif" vspace="10" width="569"/></td></tr>
# <tr><td colspan="2"><span class="red_header">Classes</span></td></tr>
# <tr><td colspan="2">
# <table>
# <tr><td valign="top" width="80"><a href="/software/labelparser.jsp">PDSLabel</a></td><td>Java class for parsing PDS Labels.</td></tr>
# <tr><td><a href="/software/ppi_option.jsp">PPIOption</a></td><td>Java class for option handling support.</td></tr>
# <tr><td><a href="/software/ppi_ruleset.jsp">PPIRuleset</a></td><td>Java class implementation of the PPI Ruleset Language.</td></tr>
# <tr><td><a href="/software/ppi_table.jsp">PPITable</a></td><td>Java class for reading and writing to tables.</td></tr>
# <!--  <tr><td><a href="/software/ppi_time.jsp">PPITime</a></td><td>Java class for maniuplating time strings.<BR></td></tr>-->
# <tr><td><a href="/software/general/pdsppi.zip">Download</a></td><td>Zip file containing source code, documentation and classes.</td></tr>
# <tr><td><a href="/software/jar/pdsppi.jar">pdsppi.jar</a></td><td>Jar file containing all PDS/PPI classes.</td></tr>
# </table>
# </td></tr>
# </table>
# </div><!-- end of centercontents -->
# <div id="rightsidebar">
# <div id="newreleases">
# <p class="sidebartitle">NEW RELEASES</p>
# <!--  <img src="/theme/images/home/ppi_home_20.gif" width="180" height="26" alt="">-->
# <div id="rightsidetext">
# <div id="newreleaseContents">
# <!-- Write New Release -->
# <span class="red_content">        2021.10.18</span><br/>
# <a href="https://pds-geosciences.wustl.edu/missions/mro/sharad_3d.htm">        MRO SHARAD 3D Radar Images</a><br/>
#         SHARAD<br/><br/>
# <span class="red_content">        2021.10.14</span><br/>
# <a href="https://pds.jpl.nasa.gov/datasearch/subscription-service/SS-20211014.shtml">        Hayabusa2 TIR Release</a><br/>
#         TIR, mission<br/><br/>
# <span class="red_content">        2021.10.01</span><br/>
# <a href="https://pds.jpl.nasa.gov/datasearch/subscription-service/SS-20211001.shtml">        Odyssey Data Release 77</a><br/>
#         GRS, RADIO SCIENCE (Releases 211,212), SPICE, THEMIS<br/><br/>
# <a href="https://pds.jpl.nasa.gov/datasearch/subscription-service/SS-Release.shtml">More.....</a>
# </div>
# </div>
# </div>
# <div id="newreleases">
# <!--  <img src="/theme/images/home/ppi_home_34.gif" width="180" height="26" alt="">-->
# <p class="sidebartitle">PDS RESOURCES</p>
# <div id="rightsidetext">
# 			Archive Planning Guide<br/>
# 			      <a href="https://pds.nasa.gov/home/proposers/proposing-programs.shtml">Individuals</a><br/>
# 			      <a href="https://pds.nasa.gov/home/proposers/Mission-Proposers-Archive-Guide-v4-r5.pdf">Missions</a><br/>
# 			Data Dictionary Search<br/>
# 				       <a href="https://pds.nasa.gov/tools/dd-search/">Lookup Tool</a><br/>
# 			      <a href="https://pds.jpl.nasa.gov/datastandards/documents/">Document</a><br/>
# <a href="https://pds.nasa.gov/datastandards/about/">PDS4 Standards Documents</a><br/>
# <!--  <a href="http://pds.nasa.gov/tools/phonebook/phonebook.cfm">PDS Phonebook</a><BR>-->
# <a href="https://pds.jpl.nasa.gov/datasearch/subscription-service/top.cfm">PDS Subscription Service</a>
# <br/>
# <br/>
# <a href="https://pds.nasa.gov/datastandards/pds3/">PDS3 Standards</a>
# </div>
# </div>
# <div id="newreleases">
# <p class="sidebartitle">OTHER RESOURCES</p>
# <div class="searchtext">
# <a href="http://www.adsabs.harvard.edu/">ADS Search</a>
# </div>
# </div>
# </div>
# <script>
#
# /*$(document).ready(function(){
# 	 //e.preventDefault();
#
# 	$.ajax({
# 		 method : "POST",
# 	      url : "https://ppi.pds.nasa.gov/new-releases",
# 	      dataType : "html",
# 	      crossDomain: true,
# 	      success: function(data) {
# 	        alert( "passing" ); // shows whole dom
# 	        var gotcha = parseHTML(data, 'wrapper');
# 	        if (gotcha) {
# 	          alert($(gotcha).html());
# 	        }
# 	      },
# 	      error : function() {
# 	        $('#newreleaseContents').html('Sorry, The requested property could not be found.');
# 	      }
# 	    });
# });
#
# */
# </script>
# </div> <!-- end of contents -->
# <div id="footer">
# <table cellpadding="0" cellspacing="0" class="footer_text" width="100%">
# <tr>
# <td width="232">
# <a href="http://www.nasa.gov/"><img border="0" height="62" src="/theme/images/home/ppi_home_46.gif"/></a></td>
# <td class="footer_text"> <a href="http://www.jpl.nasa.gov/imagepolicy/">Privacy / Copyright</a><br/>
# <a href="http://www.hq.nasa.gov/office/pao/FOIA/">Freedom of Information Act</a>
# </td>
# <td width="59">
# <a href="http://www.nasa.gov/"><img alt="" border="0" height="62" src="/theme/images/home/ppi_home_48.gif" width="59"/></a></td>
# <td class="footer_text" valign="middle" width="186">
# 				Web Master: <a href="mailto:pds_operator@igpp.ucla.edu">PDS-PPI Operator</a><br/>
# 				NASA Official: Meagan Thompson<br/>
# </td>
# </tr>
# </table>
# </div>
# </div>
# </div></body>
# </html>
